png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1637.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1638.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1639.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/164.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1640.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1641.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1642.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1643.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1644.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1645.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1646.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1647.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1648.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/1649.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/V/165.png
# ...
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/763.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/764.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/765.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/766.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/767.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/768.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/769.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/77.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/770.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/771.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/772.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/773.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/774.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/775.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/776.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/777.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/778.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/779.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/78.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/780.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/781.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/782.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/783.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/784.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/785.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/786.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/787.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/788.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/789.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/79.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/790.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/791.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/792.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/793.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/794.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/795.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/796.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/797.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/798.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/799.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/8.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/80.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/800.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/801.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/802.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/803.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/804.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/805.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/806.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/807.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/808.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/809.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/81.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/810.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/811.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/812.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/813.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/814.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/815.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/816.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/817.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/818.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/819.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/82.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/820.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/821.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/822.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/823.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/824.png
#  extracting: /content/drive/MyDrive/LIBRAS/train/Y/825.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/826.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/827.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/828.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/829.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/83.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/830.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/831.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/832.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/833.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/834.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/835.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/836.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/837.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/838.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/839.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/84.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/840.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/841.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/842.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/843.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/844.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/845.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/846.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/847.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/848.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/849.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/85.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/850.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/851.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/852.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/853.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/854.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/855.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/856.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/857.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/858.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/859.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/86.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/860.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/861.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/862.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/863.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/864.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/865.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/866.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/867.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/868.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/869.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/87.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/870.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/871.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/872.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/873.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/874.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/875.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/876.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/877.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/878.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/879.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/88.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/880.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/881.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/882.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/883.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/884.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/885.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/886.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/887.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/888.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/889.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/89.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/890.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/891.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/892.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/893.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/894.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/895.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/896.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/897.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/898.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/899.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/9.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/90.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/900.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/901.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/902.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/903.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/904.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/905.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/906.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/907.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/908.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/909.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/91.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/910.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/911.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/912.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/913.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/914.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/915.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/916.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/917.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/918.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/919.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/92.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/920.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/921.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/922.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/923.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/924.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/925.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/926.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/927.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/928.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/929.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/93.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/930.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/931.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/932.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/933.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/934.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/935.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/936.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/937.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/938.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/939.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/94.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/940.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/941.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/942.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/943.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/944.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/945.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/946.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/947.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/948.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/949.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/95.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/950.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/951.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/952.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/953.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/954.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/955.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/956.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/957.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/958.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/959.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/96.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/960.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/961.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/962.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/963.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/964.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/965.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/966.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/967.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/968.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/969.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/97.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/970.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/971.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/972.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/973.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/974.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/975.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/976.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/977.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/978.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/979.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/98.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/980.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/981.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/982.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/983.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/984.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/985.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/986.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/987.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/988.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/989.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/99.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/990.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/991.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/992.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/993.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/994.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/995.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/996.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/997.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/998.png
#   inflating: /content/drive/MyDrive/LIBRAS/train/Y/999.png

# %% [markdown]
# # Preprocessing

# %%
transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1, hue=0.1),
        transforms.RandomAffine(degrees=40, translate=None, scale=(1, 2), shear=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
data_dir = "/content/drive/MyDrive/LIBRAS/"

image_datasets = {
    x: datasets.ImageFolder(
        root=os.path.join(data_dir, x), 
        transform=transform
    )
    for x in ['train', 'test']
}
dataloaders = {
    x: torch.utils.data.DataLoader(
        image_datasets[x], batch_size=8,
        shuffle=True, num_workers=2
    )
    for x in ['train', 'test']
}
pathloaders = {
    x: torch.utils.data.DataLoader(
        image_datasets[x].imgs, batch_size=8,
        shuffle=True, num_workers=2
    )
    for x in ['train', 'test']
}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train',  'test']}

# %%
for x in ['train', 'test']:
    print("Loaded {} images in {}".format(dataset_sizes[x], x))
    
print("Classes: ")

label = image_datasets['test'].classes
print(image_datasets['train'].classes)
print(label)
# Out:
# Loaded 35004 images in train
# Loaded 11534 images in test
# Classes:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'Y']
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'Y']

# %% [markdown]
# # Creating Model

# %%
num_classes = len(os.listdir(data_dir + 'train'))
num_epochs = 10
batch_size = 64
learning_rate = 0.0005

model = torchvision.models.vgg19_bn(weights="IMAGENET1K_V1")

if use_gpu:
  model.to(device)

# Newly created modules have require_grad=True by default
num_features = model.classifier[6].in_features
features = list(model.classifier.children())[:-1] # Remove last layer
features.extend([nn.Linear(num_features, num_classes)]) # Add our layer with 4 outputs
model.classifier = nn.Sequential(*features) # Replace the model classifier

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# 100%|██████████| 548M/548M [00:17<00:00, 32.0MB/s]

# %% [markdown]
# # Visualizing

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated
    
def show_databatch(inputs, classes):
    out = torchvision.utils.make_grid(inputs)
    imshow(out, title=[label[x] for x in classes])

# %%
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[label[x] for x in classes])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    
    # Set model for evaluation
    model.train(False)
    model.eval() 
    
    images_so_far = 0

    for i, data in enumerate(dataloaders['test']):
        inputs, labels = data
        size = inputs.size()[0]
        
        if use_gpu:
            with torch.no_grad():
                inputs, labels = inputs.to(device), labels.to(device)
        else:
            with torch.no_grad():
                inputs, labels = inputs, labels
        
        outputs = model(inputs)
        
        _, preds = torch.max(outputs.data, 1)
        predicted_labels = [preds[j] for j in range(inputs.size()[0])]
        
        print("Ground truth:")
        show_databatch(inputs.data.cpu(), labels.data.cpu())
        print("Prediction:")
        show_databatch(inputs.data.cpu(), predicted_labels)
        
        del inputs, labels, outputs, preds, predicted_labels
        torch.cuda.empty_cache()
        
        images_so_far += size
        if images_so_far >= num_images:
            break
        
    model.train(mode=was_training)

# %%
visualize_model(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-8356e88ead70> in <cell line: 1>()
# ----> 1 visualize_model(model)
#
# <ipython-input-10-d86e856aac79> in visualize_model(model, num_images)
#      19                 inputs, labels = inputs, labels
#      20
# ---> 21         outputs = model(inputs)
#      22
#      23         _, preds = torch.max(outputs.data, 1)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      67         x = self.avgpool(x)
#      68         x = torch.flatten(x, 1)
# ---> 69         x = self.classifier(x)
#      70         return x
#      71
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %% [markdown]
# # Training

# %%
def train_model(vgg, criterion, optimizer, scheduler, num_epochs=5):
    since = time.time()
    best_model_wts = copy.deepcopy(vgg.state_dict())
    best_acc = 0.0
    
    avg_loss = 0
    avg_acc = 0
    avg_loss_val = 0
    avg_acc_val = 0
    
    train_batches = len(dataloaders['train'])
    
    loss_values = []
    acc_values = []
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs))
        print('-' * 10)
        
        loss_train = 0
        loss_val = 0
        acc_train = 0
        
        vgg.train(True)
        
        for i, data in enumerate(dataloaders['train']):
            
            print("\rTraining batch {}/{}".format(i+1, train_batches), end='', flush=True)
                
            
                
            inputs, labels= data
            
            if use_gpu:
                with torch.no_grad():
                    inputs, labels = inputs.cuda(), labels.cuda()
            else:
                with torch.no_grad():
                    inputs, labels = inputs, labels
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            loss_train += loss.item()
            acc_train += torch.sum(preds == labels.data)
            
            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
        
        print()
        # * 2 as we only used half of the dataset
        avg_loss = loss_train  / dataset_sizes['train']
        avg_acc = acc_train  / dataset_sizes['train']
        loss_values.append(avg_loss)
        acc_values.append(avg_acc)
        vgg.train(False)
        vgg.eval()
            

        
        print()
        print("Epoch {} result: ".format(epoch))
        print("Avg loss (train): {:.4f}".format(avg_loss))
        print("Avg acc (train): {:.4f}".format(avg_acc))

        print('-' * 10)
        print()
        
        if avg_acc > best_acc:
            best_acc = avg_acc
            best_model_wts = copy.deepcopy(vgg.state_dict())
        
    elapsed_time = time.time() - since
    print()
    print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Best acc: {:.4f}".format(best_acc))
    
    vgg.load_state_dict(best_model_wts)
    return vgg,acc_values,loss_values

# %%
model,acc,loss = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=10)
torch.save(model.state_dict(),'VGG19_libras.pt')
# Out:
# Epoch 0/10
# ----------
# Training batch 21/4340
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-835e8d700790> in <cell line: 1>()
# ----> 1 model,acc,loss = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=10)
#       2 torch.save(model.state_dict(),'VGG19_libras.pt')
#
# <ipython-input-20-b80c821ec9e5> in train_model(vgg, criterion, optimizer, scheduler, num_epochs)
#      45             loss = criterion(outputs, labels)
#      46
# ---> 47             loss.backward()
#      48             optimizer.step()
#      49
#
# /usr/local/lib/python3.9/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
plt.plot([it.item() for it in loss[:-1]])
plt.title("VGG loss")

# %% [markdown]
# # Evaluating

# %%
def eval_model(model, criterion):
    y_true = []
    y_pred = []
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0
    
    test_batches = len(dataloaders['test'])
    print("Evaluating model")
    print('-' * 10)
    
    for i, data in enumerate(dataloaders['test']):
        if i % 100 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        model.train(False)
        model.eval()
        
        inputs, labels = data
        
        y_true = y_true + labels.tolist()
        
        if use_gpu:
            with torch.no_grad():
                inputs, labels = inputs.cuda(), labels.cuda()
        else:
            with torch.no_grad():
                inputs, labels = inputs, labels

        outputs = model(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)
        #print(preds)
        y_pred = y_pred + preds.tolist()
        
        loss_test += loss.item()
        acc_test += torch.sum(preds == labels.data)

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()
        
    avg_loss = loss_test / dataset_sizes['test']
    avg_acc = acc_test / dataset_sizes['test']
    
    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Avg loss (test): {:.4f}".format(avg_loss))
    print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)
    return y_true,y_pred

# %%
eval_model(model, criterion)
# Out:
# Evaluating model
# ----------
# Test batch 0/1442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-477485d1477c> in <cell line: 1>()
# ----> 1 eval_model(model, criterion)
#
# <ipython-input-22-95c15a1f255f> in eval_model(model, criterion)
#      30                 inputs, labels = inputs, labels
#      31
# ---> 32         outputs = model(inputs)
#      33
#      34         _, preds = torch.max(outputs.data, 1)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      64
#      65     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 66         x = self.features(x)
#      67         x = self.avgpool(x)
#      68         x = torch.flatten(x, 1)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:
